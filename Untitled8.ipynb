# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsa394/HAFSA./blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# qstn 1

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/aids/fruits_data.csv')
print(df.shape)

print(df.to_string())
# Out:
# (10, 6)
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  Water Melons(1)
# 0  01-01-2022       230.0             46.0         65.0       184.0              NaN
# 1  01-02-2022       237.0             50.0         72.0       173.0             72.0
# 2  01-03-2022       259.0              NaN          NaN         NaN             93.0
# 3  01-04-2022         NaN             41.0         75.0       175.0             74.0
# 4  01-05-2022       240.0             48.0          NaN       185.0             84.0
# 5  01-06-2022       234.0             45.0         66.0       194.0             93.0
# 6  01-07-2022         NaN              NaN         70.0       174.0              NaN
# 7  01-08-2022       236.0             46.0         66.0       187.0             86.0
# 8  01-09-2022       232.0             41.0         71.0         NaN             93.0
# 9  01-10-2022       240.0             48.0          NaN       198.0             97.0

# %%
print(df.columns.tolist())
# Out:
# ['date', 'apple(1kg)', 'banana(1 dozen)', 'grapes(1kg)', 'mango(1kg)', 'Water Melons(1)']

# %%
print(df)
print(df.head())
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0             46.0         65.0       184.0
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 2  01-03-2022       259.0              NaN          NaN         NaN
# 3  01-04-2022         NaN             41.0         75.0       175.0
# 4  01-05-2022       240.0             48.0          NaN       185.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 6  01-07-2022         NaN              NaN         70.0       174.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
# 8  01-09-2022       232.0             41.0         71.0         NaN
# 9  01-10-2022       240.0             48.0          NaN       198.0
#
#    Water Melons(1)
# 0              NaN
# 1             72.0
# 2             93.0
# 3             74.0
# 4             84.0
# 5             93.0
# 6              NaN
# 7             86.0
# 8             93.0
# ...

# %% [markdown]
# qstn 2

# %%
new_df = df.fillna(value='-1')
new_df
# Out:
#          date apple(1kg) banana(1 dozen) grapes(1kg) mango(1kg)  \
# 0  01-01-2022      230.0            46.0        65.0      184.0
# 1  01-02-2022      237.0            50.0        72.0      173.0
# 2  01-03-2022      259.0              -1          -1         -1
# 3  01-04-2022         -1            41.0        75.0      175.0
# 4  01-05-2022      240.0            48.0          -1      185.0
# 5  01-06-2022      234.0            45.0        66.0      194.0
# 6  01-07-2022         -1              -1        70.0      174.0
# 7  01-08-2022      236.0            46.0        66.0      187.0
# 8  01-09-2022      232.0            41.0        71.0         -1
# 9  01-10-2022      240.0            48.0          -1      198.0
#
#   Water Melons(1)
# 0              -1
# 1            72.0
# 2            93.0
# 3            74.0
# 4            84.0
# 5            93.0
# 6              -1
# 7            86.0
# 8            93.0
# 9            97.0

# %% [markdown]
# qstn3

# %%
new_df = df.copy()

# Convert relevant columns to numeric, coercing any non-numeric values (like '-1') to NaN
new_df['apple(1kg)'] = pd.to_numeric(new_df['apple(1kg)'], errors='coerce')
new_df['banana(1 dozen)'] = pd.to_numeric(new_df['banana(1 dozen)'], errors='coerce')
new_df['grapes(1kg)'] = pd.to_numeric(new_df['grapes(1kg)'], errors='coerce')
new_df['mango(1kg)'] = pd.to_numeric(new_df['mango(1kg)'], errors='coerce')
new_df['Water Melons(1)'] = pd.to_numeric(new_df['Water Melons(1)'], errors='coerce')

# Now fill the NaNs with mean or median
new_df['apple(1kg)']   = new_df['apple(1kg)'].fillna(new_df['apple(1kg)'].mean())
new_df['banana(1 dozen)'] = new_df['banana(1 dozen)'].fillna(new_df['banana(1 dozen)'].mean())
new_df['grapes(1kg)']  = new_df['grapes(1kg)'].fillna(new_df['grapes(1kg)'].median())
new_df['mango(1kg)']   = new_df['mango(1kg)'].fillna(new_df['mango(1kg)'].median())
new_df['Water Melons(1)'] = new_df['Water Melons(1)'].fillna('Not Available')
new_df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0           46.000         65.0       184.0
# 1  01-02-2022       237.0           50.000         72.0       173.0
# 2  01-03-2022       259.0           45.625         70.0       184.5
# 3  01-04-2022       238.5           41.000         75.0       175.0
# 4  01-05-2022       240.0           48.000         70.0       185.0
# 5  01-06-2022       234.0           45.000         66.0       194.0
# 6  01-07-2022       238.5           45.625         70.0       174.0
# 7  01-08-2022       236.0           46.000         66.0       187.0
# 8  01-09-2022       232.0           41.000         71.0       184.5
# 9  01-10-2022       240.0           48.000         70.0       198.0
#
#   Water Melons(1)
# 0   Not Available
# 1            72.0
# 2            93.0
# 3            74.0
# 4            84.0
# 5            93.0
# 6   Not Available
# 7            86.0
# 8            93.0
# 9            97.0

# %% [markdown]
# qstn4

# %%
new_df = df.ffill()
new_df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0             46.0         65.0       184.0
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 2  01-03-2022       259.0             50.0         72.0       173.0
# 3  01-04-2022       259.0             41.0         75.0       175.0
# 4  01-05-2022       240.0             48.0         75.0       185.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 6  01-07-2022       234.0             45.0         70.0       174.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
# 8  01-09-2022       232.0             41.0         71.0       187.0
# 9  01-10-2022       240.0             48.0         71.0       198.0
#
#    Water Melons(1)
# 0              NaN
# 1             72.0
# 2             93.0
# 3             74.0
# 4             84.0
# 5             93.0
# 6             93.0
# 7             86.0
# 8             93.0
# ...

# %% [markdown]
# qstn5

# %%
new_df = df.dropna(thresh=4)
new_df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 0  01-01-2022       230.0             46.0         65.0       184.0
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 3  01-04-2022         NaN             41.0         75.0       175.0
# 4  01-05-2022       240.0             48.0          NaN       185.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
# 8  01-09-2022       232.0             41.0         71.0         NaN
# 9  01-10-2022       240.0             48.0          NaN       198.0
#
#    Water Melons(1)
# 0              NaN
# 1             72.0
# 3             74.0
# 4             84.0
# 5             93.0
# 7             86.0
# 8             93.0
# 9             97.0

# %% [markdown]
# qstn6

# %%
new_df = df.dropna()
new_df.to_csv('final_data.csv', index=False)
new_df
# Out:
#          date  apple(1kg)  banana(1 dozen)  grapes(1kg)  mango(1kg)  \
# 1  01-02-2022       237.0             50.0         72.0       173.0
# 5  01-06-2022       234.0             45.0         66.0       194.0
# 7  01-08-2022       236.0             46.0         66.0       187.0
#
#    Water Melons(1)
# 1             72.0
# 5             93.0
# 7             86.0
